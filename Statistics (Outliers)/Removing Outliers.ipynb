# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("income.csv", names=['Name','Income'], skiprows=[0])

# %%
df

# %%
df.describe()

# %%
percentile_99 = df.Income.quantile(0.99)

# %%
percentile_99

# %%
df[df.Income<=percentile_99]

# %%
df

# %%
df.Income.median()

# %%
df_new=df.fillna(df.Income.median())

# %%
df_new

# %%
df = pd.read_csv("AB.CSV")
df
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
price=df.price
price.describe()
# Out:
# count    48895.000000
# mean       152.720687
# std        240.154170
# min          0.000000
# 25%         69.000000
# 50%        106.000000
# 75%        175.000000
# max      10000.000000
# Name: price, dtype: float64

# %%
Q1,Q3 = np.percentile(price,[25,75])
IQR = Q3 - Q1
print(Q1,Q3)
# Out:
# 69.0 175.0

# %%
lower_fence = Q1 - (1.5 * IQR)
lower_fence
# Out:
# -90.0

# %%
higher_fence = Q3 + (1.5 * IQR)
higher_fence
# Out:
# 334.0

# %%
outliers = []
def detect_outliers(l,h):
    for i in price:
        if i > h or i<l:
            outliers.append(i)
    return outliers

# %%
detect_outliers(lower_fence,higher_fence)
# Out:
# [375,
#  800,
#  500,
#  350,
#  400,
#  475,
#  350,
#  500,
#  500,
#  390,
#  575,
#  500,
#  350,
#  349,
#  349,
#  650,
#  599,
#  395,
#  495,
#  375,
#  451,
#  450,
#  500,
#  350,
#  400,
#  2000,
#  500,
#  429,
#  350,
#  350,
#  399,
#  438,
#  700,
#  400,
#  850,
#  349,
#  599,
#  495,
#  760,
#  375,
#  485,
#  350,
#  1300,
#  402,
#  800,
#  385,
#  450,
#  499,
#  500,
#  387,
#  350,
#  3000,
#  549,
#  350,
#  500,
#  350,
#  395,
#  1300,
#  500,
#  380,
#  450,
#  350,
#  385,
#  499,
#  349,
#  800,
#  349,
#  350,
#  350,
#  375,
#  450,
#  500,
#  399,
#  700,
#  500,
#  400,
#  1000,
#  700,
#  350,
#  433,
#  595,
#  349,
#  2000,
#  355,
#  550,
#  380,
#  900,
#  399,
#  425,
#  495,
#  350,
#  375,
#  625,
#  350,
#  575,
#  400,
#  500,
#  600,
#  390,
#  350,
#  350,
#  465,
#  349,
#  340,
#  4000,
#  500,
#  400,
#  400,
#  349,
#  495,
#  999,
#  800,
#  339,
#  500,
#  2500,
#  890,
#  399,
#  349,
#  400,
#  650,
#  350,
#  349,
#  420,
#  950,
# ...

# %%
outliers=[]
def detect_outliers(data):
    threshold = 3 #3rd standard deviation 
    mean = np.mean(data)
    std = np.std(data)
    
    for i in data:
        z_score = (i-mean)/std
        if np.abs(z_score) > threshold:
            outliers.append(i)
    return outliers

# %%
detect_outliers(price)
# Out:
# [2000,
#  1300,
#  3000,
#  1300,
#  1000,
#  2000,
#  900,
#  4000,
#  999,
#  2500,
#  890,
#  950,
#  1000,
#  1395,
#  1000,
#  1000,
#  1500,
#  1899,
#  5000,
#  1100,
#  1200,
#  1700,
#  1999,
#  1500,
#  1000,
#  1000,
#  6000,
#  900,
#  900,
#  2000,
#  2000,
#  950,
#  1500,
#  900,
#  1500,
#  1000,
#  4000,
#  1000,
#  1200,
#  5250,
#  1500,
#  1500,
#  1000,
#  1000,
#  1500,
#  1550,
#  1000,
#  1250,
#  1485,
#  6500,
#  2750,
#  1500,
#  2500,
#  3750,
#  1600,
#  1000,
#  1000,
#  900,
#  975,
#  2300,
#  5000,
#  4500,
#  8000,
#  950,
#  1000,
#  1000,
#  1400,
#  900,
#  1050,
#  2695,
#  1000,
#  2000,
#  985,
#  1500,
#  1000,
#  895,
#  1000,
#  1000,
#  9999,
#  2400,
#  2000,
#  1000,
#  995,
#  1763,
#  1450,
#  2000,
#  2000,
#  2000,
#  2000,
#  1200,
#  950,
#  900,
#  1000,
#  1495,
#  888,
#  2000,
#  900,
#  999,
#  10000,
#  1600,
#  1500,
#  1200,
#  1100,
#  1195,
#  999,
#  2000,
#  1000,
#  2000,
#  1170,
#  1150,
#  1000,
#  899,
#  1200,
# ...

# %%
df[(df.price<higher_fence)]
# Out:
#              id                                               name   host_id  \
# 0          2539                 Clean & quiet apt home by the park      2787
# 1          2595                              Skylit Midtown Castle      2845
# 2          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3          3831                    Cozy Entire Floor of Brownstone      4869
# 4          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# ...         ...                                                ...       ...
# 48890  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48891  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48892  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48893  36485609               43rd St. Time Square-cozy single bed  30985759
# 48894  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
df2 = df[(df.price>lower_fence)&(df.price<higher_fence)]

# %%
df2.shape
# Out:
# (45918, 16)

# %%
df2.sample(5)
# Out:
#              id                                               name    host_id  \
# 31822  24831549                     Sleek Studio in FiDi by Sonder   12243051
# 1311     573671  Luminous Modern Apt Share for Young Professionals    2822805
# 9505    7304034   SPACIOUS Lower East Side DUPLEX 3 bed 2 ba COMFY   37623794
# 16512  13234457                  Cozy Clinton Hill Crib On Classon       2868
# 26654  21191546       Monroe Manor - 3 bedroom, 2 full bath duplex  153044885
#
#       host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 31822    Sonder           Manhattan  Financial District  40.70571  -74.00833
# 1311      Ollie            Brooklyn  Bedford-Stuyvesant  40.68586  -73.95010
# 9505     Amanda           Manhattan        East Village  40.72545  -73.98802
# 16512  Letha M.            Brooklyn  Bedford-Stuyvesant  40.68258  -73.95871
# 26654       Joy            Brooklyn  Bedford-Stuyvesant  40.68747  -73.92879
#
# ...

# %%
df2.price.describe()
# Out:
# count    45918.000000
# mean       119.947014
# std         68.117249
# min          0.000000
# 25%         65.000000
# 50%        100.000000
# 75%        159.000000
# max        333.000000
# Name: price, dtype: float64

# %%
min_thresold, max_thresold = df.price.quantile([0.01,0.999])
min_thresold, max_thresold
# Out:
# (30.0, 3000.0)

# %%
df2 = df[(df.price>min_thresold)&(df.price<max_thresold)]
df2.shape
# Out:
# (48183, 16)

# %%
df2.price.describe()
# Out:
# count    48183.000000
# mean       148.772036
# std        153.594795
# min         31.000000
# 25%         70.000000
# 50%        110.000000
# 75%        179.000000
# max       2999.000000
# Name: price, dtype: float64
